# %%
import main as a
import pickle as pkl
import torch.nn as nn
import torch
from torch.utils.data import DataLoader
from importlib import reload
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import f1_score
import pandas as pd
from sklearn.impute import KNNImputer
from sklearn.preprocessing import MinMaxScaler

# %%
data = pd.read_csv("/Users/aviadsusman/Documents/Python_Projects/FeatureLevelAttention/FLA/data/COVID-19 data/Basics/concatenated.csv")
labels = pd.read_csv("/Users/aviadsusman/Documents/Python_Projects/FeatureLevelAttention/FLA/data/COVID-19 data/Basics/outcome.csv")

# %%
X_raw = data.drop(columns=['NEW_MASKED_MRN']).to_numpy()
y = labels['DECEASED_INDICATOR'].to_numpy()
y_counts = np.unique(y, return_counts=True)[1]
weight = torch.tensor([y_counts[0]/y_counts[1]], dtype=torch.float32)

# %%
imputer = KNNImputer(n_neighbors=5)
X_imputed_not_norm = imputer.fit_transform(X_raw)
scaler = MinMaxScaler()
X = scaler.fit_transform(X_imputed_not_norm)

# %%
X.shape
# Out:
# (4783, 98)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, stratify=y, test_size=0.2, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train,y_train, stratify=y_train, test_size=0.1, random_state=42)

# %%
reload(a)
# Out:
# <module 'main' from '/Users/aviadsusman/Documents/Python_Projects/FeatureLevelAttention/FLA/main.py'>

# %%
train_dataset = a.npDataset(X_train,y_train)
test_dataset = a.npDataset(X_test,y_test)
val_dataset = a.npDataset(X_val,y_val)
batch_size = 100

train_loader = DataLoader(train_dataset, batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %%
hidden_dims = [50,25,10]
attn_heads = 0
model = a.FLANN(input_dim=98, hidden_dims=hidden_dims, output_dim=1, attn_heads=attn_heads, activation=nn.ReLU())

# %%
criterion = nn.BCEWithLogitsLoss(pos_weight=weight)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
num_epochs = 500
best_val_loss = float('inf')
best_model = None
patience = 10
early_stop_counter = 0
for epoch in range(num_epochs):
    model.train()
    for inputs, labels in train_loader:
        optimizer.zero_grad()
        outputs = model(inputs)
        labels = labels.unsqueeze(1)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

    model.eval()
    val_losses = []
    for inputs, labels in val_loader:
        with torch.no_grad():
            outputs = model(inputs)
            labels = labels.unsqueeze(1)
            val_loss = criterion(outputs, labels)
            val_losses.append(val_loss.item())
    
    avg_val_loss = np.mean(val_losses)
    print(f'Epoch {epoch+1}, Validation Loss: {avg_val_loss:.4f}')
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        best_model = model.state_dict()
        early_stop_counter = 0
    else:
        early_stop_counter += 1
    
    if early_stop_counter >= patience:
        print(f'Early stopping after epoch {epoch+1} with validation loss {best_val_loss:.4f}')
        break

model.load_state_dict(best_model)
# model.eval()

# %%
test_losses = []
test_predictions = []
test_true_labels = []

for inputs, labels in test_loader:
    with torch.no_grad():
        outputs = model(inputs)
        labels = labels.unsqueeze(1)
        test_loss = criterion(outputs, labels)
        test_losses.append(test_loss.item())
        test_predictions.extend(outputs.cpu().numpy())
        test_true_labels.extend(labels.cpu().numpy())

avg_test_loss = np.mean(test_losses)
test_predictions = [y>0.5 for y in test_predictions]
test_score = f1_score(test_true_labels, test_predictions)
print(f'Test Loss: {avg_test_loss:.4f}, Test Score: {test_score:.4f}')

# %%
head_counts = [20,25]#[0,5,10,15]
test_prediction_dict = {h: [] for h in head_counts}
test_label_list = []
losses = {h: [] for h in head_counts}
for seed in range(10):
    for head in head_counts:
        print(f'seed {seed+1}, with {head} heads')
        #split data
        X_train, X_test, y_train, y_test = train_test_split(X,y, stratify=y, test_size=0.2, random_state=seed)
        X_train, X_val, y_train, y_val = train_test_split(X_train,y_train, stratify=y_train, test_size=0.1, random_state=seed)
        train_dataset = a.npDataset(X_train,y_train)
        test_dataset = a.npDataset(X_test,y_test)
        val_dataset = a.npDataset(X_val,y_val)
        batch_size = 100
        train_loader = DataLoader(train_dataset, batch_size, shuffle=True)
        test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
        val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

        #make model
        hidden_dims = [50,25,10]
        attn_heads = head
        model = a.FLANN(input_dim=98, hidden_dims=hidden_dims, output_dim=1, attn_heads=attn_heads, activation=nn.ReLU())
        criterion = nn.BCEWithLogitsLoss(pos_weight=weight)
        optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

        #train
        num_epochs = 500
        best_val_loss = float('inf')
        best_model = None
        patience = 10
        early_stop_counter = 0
        for epoch in range(num_epochs):
            model.train()
            for inputs, labels in train_loader:
                optimizer.zero_grad()
                outputs = model(inputs)
                labels = labels.unsqueeze(1)
                loss = criterion(outputs, labels)
                loss.backward()
                optimizer.step()

            model.eval()
            val_losses = []
            for inputs, labels in val_loader:
                with torch.no_grad():
                    outputs = model(inputs)
                    labels = labels.unsqueeze(1)
                    val_loss = criterion(outputs, labels)
                    val_losses.append(val_loss.item())
            
            avg_val_loss = np.mean(val_losses)
            print(f'Epoch {epoch+1}, Validation Loss: {avg_val_loss:.4f}')
            if avg_val_loss < best_val_loss:
                best_val_loss = avg_val_loss
                best_model = model.state_dict()
                early_stop_counter = 0
            else:
                early_stop_counter += 1
            
            if early_stop_counter >= patience:
                print(f'Early stopping after epoch {epoch+1} with validation loss {best_val_loss:.4f}')
                break
            
        model.load_state_dict(best_model)

        #eval
        test_losses = []
        test_predictions = []
        test_true_labels = []

        for inputs, labels in test_loader:
            with torch.no_grad():
                outputs = model(inputs)
                labels = labels.unsqueeze(1)
                test_loss = criterion(outputs, labels)
                test_losses.append(test_loss.item())
                test_predictions.extend(outputs.cpu().numpy())
                test_true_labels.extend(labels.cpu().numpy())
        avg_test_loss = np.mean(test_losses)
        test_predictions_f1 = [y>0.5 for y in test_predictions]
        test_score = f1_score(test_true_labels, test_predictions_f1)
        print(f'Test Loss: {avg_test_loss:.4f}, Test Score: {test_score:.4f} for seed {seed+1} and {head} heads.')
        if head == 0:
            test_label_list.append(test_true_labels)
        test_prediction_dict[head].append(test_predictions)
        losses[head].append(avg_test_loss)
with open ("/Users/aviadsusman/Documents/Python_Projects/FeatureLevelAttention/FLA/results/covid/test_pred_dict_20s.pkl", "wb") as file:
    pkl.dump(test_prediction_dict, file=file)
with open ("/Users/aviadsusman/Documents/Python_Projects/FeatureLevelAttention/FLA/results/covid/test_losses_dict_20s.pkl", "wb") as file:
    pkl.dump(losses, file=file)
with open ("/Users/aviadsusman/Documents/Python_Projects/FeatureLevelAttention/FLA/results/covid/test_labels_20s.pkl", "wb") as file:
    pkl.dump(test_label_list, file=file)
# Out:
# seed 1, with 20 heads
# Epoch 1, Validation Loss: 0.9845
# Epoch 2, Validation Loss: 0.9430
# Epoch 3, Validation Loss: 0.8871
# Epoch 4, Validation Loss: 0.9084
# Epoch 5, Validation Loss: 0.8520
# Epoch 6, Validation Loss: 0.8356
# Epoch 7, Validation Loss: 0.8425
# Epoch 8, Validation Loss: 0.8188
# Epoch 9, Validation Loss: 0.8194
# Epoch 10, Validation Loss: 0.8028
# Epoch 11, Validation Loss: 0.7952
# Epoch 12, Validation Loss: 0.7998
# Epoch 13, Validation Loss: 0.7939
# Epoch 14, Validation Loss: 0.8358
# Epoch 15, Validation Loss: 0.7869
# Epoch 16, Validation Loss: 0.7903
# Epoch 17, Validation Loss: 0.7964
# Epoch 18, Validation Loss: 0.7777
# Epoch 19, Validation Loss: 0.7945
# Epoch 20, Validation Loss: 0.7827
# Epoch 21, Validation Loss: 0.7741
# Epoch 22, Validation Loss: 0.7792
# Epoch 23, Validation Loss: 0.7747
# Epoch 24, Validation Loss: 0.7891
# Epoch 25, Validation Loss: 0.7642
# Epoch 26, Validation Loss: 0.7586
# Epoch 27, Validation Loss: 0.7984
# Epoch 28, Validation Loss: 0.7551
# Epoch 29, Validation Loss: 0.7448
# Epoch 30, Validation Loss: 0.7572
# Epoch 31, Validation Loss: 0.7341
# Epoch 32, Validation Loss: 0.7339
# Epoch 33, Validation Loss: 0.7575
# Epoch 34, Validation Loss: 0.7348
# Epoch 35, Validation Loss: 0.7250
# Epoch 36, Validation Loss: 0.7286
# Epoch 37, Validation Loss: 0.7204
# Epoch 38, Validation Loss: 0.7347
# Epoch 39, Validation Loss: 0.7817
# Epoch 40, Validation Loss: 0.7279
# Epoch 41, Validation Loss: 0.7266
# Epoch 42, Validation Loss: 0.7177
# Epoch 43, Validation Loss: 0.7343
# Epoch 44, Validation Loss: 0.7522
# Epoch 45, Validation Loss: 0.7394
# Epoch 46, Validation Loss: 0.7366
# Epoch 47, Validation Loss: 0.7596
# Epoch 48, Validation Loss: 0.7285
# Epoch 49, Validation Loss: 0.7450
# Epoch 50, Validation Loss: 0.7618
# Epoch 51, Validation Loss: 0.7159
# Epoch 52, Validation Loss: 0.7330
# Epoch 53, Validation Loss: 0.7629
# Epoch 54, Validation Loss: 0.7128
# Epoch 55, Validation Loss: 0.7627
# Epoch 56, Validation Loss: 0.7368
# Epoch 57, Validation Loss: 0.7327
# Epoch 58, Validation Loss: 0.8186
# Epoch 59, Validation Loss: 0.7278
# Epoch 60, Validation Loss: 0.7983
# Epoch 61, Validation Loss: 0.7418
# Epoch 62, Validation Loss: 0.7264
# Epoch 63, Validation Loss: 0.7183
# Epoch 64, Validation Loss: 0.7359
# Early stopping after epoch 64 with validation loss 0.7128
# Test Loss: 0.7913, Test Score: 0.5759 for seed 1 and 20 heads.
# seed 1, with 25 heads
# Epoch 1, Validation Loss: 0.9989
# Epoch 2, Validation Loss: 0.9515
# Epoch 3, Validation Loss: 0.9135
# Epoch 4, Validation Loss: 0.8336
# Epoch 5, Validation Loss: 0.8051
# Epoch 6, Validation Loss: 1.0696
# Epoch 7, Validation Loss: 0.8404
# Epoch 8, Validation Loss: 0.7963
# Epoch 9, Validation Loss: 0.7582
# Epoch 10, Validation Loss: 0.7522
# Epoch 11, Validation Loss: 0.7823
# Epoch 12, Validation Loss: 0.7343
# Epoch 13, Validation Loss: 0.7844
# Epoch 14, Validation Loss: 0.7689
# Epoch 15, Validation Loss: 0.7243
# Epoch 16, Validation Loss: 0.6980
# Epoch 17, Validation Loss: 0.7055
# Epoch 18, Validation Loss: 0.7171
# Epoch 19, Validation Loss: 0.7891
# Epoch 20, Validation Loss: 0.6969
# Epoch 21, Validation Loss: 0.6984
# Epoch 22, Validation Loss: 0.7067
# Epoch 23, Validation Loss: 0.6944
# Epoch 24, Validation Loss: 0.6953
# Epoch 25, Validation Loss: 0.6900
# Epoch 26, Validation Loss: 0.6957
# Epoch 27, Validation Loss: 0.7350
# Epoch 28, Validation Loss: 0.7240
# Epoch 29, Validation Loss: 0.7182
# Epoch 30, Validation Loss: 0.6932
# Epoch 31, Validation Loss: 0.6801
# Epoch 32, Validation Loss: 0.6801
# Epoch 33, Validation Loss: 0.6825
# Epoch 34, Validation Loss: 0.6984
# Epoch 35, Validation Loss: 0.7003
# Epoch 36, Validation Loss: 0.6866
# Epoch 37, Validation Loss: 0.7217
# Epoch 38, Validation Loss: 0.6837
# Epoch 39, Validation Loss: 0.6838
# Epoch 40, Validation Loss: 0.6641
# Epoch 41, Validation Loss: 0.6949
# Epoch 42, Validation Loss: 0.7581
# Epoch 43, Validation Loss: 0.6729
# Epoch 44, Validation Loss: 0.6845
# Epoch 45, Validation Loss: 0.6937
# Epoch 46, Validation Loss: 0.6884
# Epoch 47, Validation Loss: 0.6634
# Epoch 48, Validation Loss: 0.6704
# Epoch 49, Validation Loss: 0.6989
# Epoch 50, Validation Loss: 0.6845
# Epoch 51, Validation Loss: 0.6787
# Epoch 52, Validation Loss: 0.6716
# Epoch 53, Validation Loss: 0.6836
# Epoch 54, Validation Loss: 0.7131
# Epoch 55, Validation Loss: 0.6922
# Epoch 56, Validation Loss: 0.6720
# Epoch 57, Validation Loss: 0.6868
# Early stopping after epoch 57 with validation loss 0.6634
# Test Loss: 0.7885, Test Score: 0.5693 for seed 1 and 25 heads.
# seed 2, with 20 heads
# Epoch 1, Validation Loss: 0.9165
# Epoch 2, Validation Loss: 0.8918
# Epoch 3, Validation Loss: 0.8161
# Epoch 4, Validation Loss: 0.8181
# Epoch 5, Validation Loss: 0.7918
# Epoch 6, Validation Loss: 0.7654
# Epoch 7, Validation Loss: 0.7545
# Epoch 8, Validation Loss: 0.7734
# Epoch 9, Validation Loss: 0.8018
# Epoch 10, Validation Loss: 0.8053
# Epoch 11, Validation Loss: 0.7939
# Epoch 12, Validation Loss: 0.7747
# Epoch 13, Validation Loss: 0.7662
# Epoch 14, Validation Loss: 0.7885
# Epoch 15, Validation Loss: 0.7849
# Epoch 16, Validation Loss: 0.7755
# Epoch 17, Validation Loss: 0.8267
# Early stopping after epoch 17 with validation loss 0.7545
# Test Loss: 0.8151, Test Score: 0.5333 for seed 2 and 20 heads.
# seed 2, with 25 heads
# Epoch 1, Validation Loss: 0.9499
# Epoch 2, Validation Loss: 0.9067
# Epoch 3, Validation Loss: 0.8719
# Epoch 4, Validation Loss: 0.8340
# Epoch 5, Validation Loss: 0.8254
# Epoch 6, Validation Loss: 0.8176
# Epoch 7, Validation Loss: 0.7954
# Epoch 8, Validation Loss: 0.7862
# Epoch 9, Validation Loss: 0.7824
# Epoch 10, Validation Loss: 0.7817
# Epoch 11, Validation Loss: 0.7994
# Epoch 12, Validation Loss: 0.7810
# Epoch 13, Validation Loss: 0.7982
# Epoch 14, Validation Loss: 0.7930
# Epoch 15, Validation Loss: 0.7822
# Epoch 16, Validation Loss: 0.7770
# Epoch 17, Validation Loss: 0.7641
# Epoch 18, Validation Loss: 0.7523
# Epoch 19, Validation Loss: 0.7555
# Epoch 20, Validation Loss: 0.7504
# Epoch 21, Validation Loss: 0.7620
# Epoch 22, Validation Loss: 0.7784
# Epoch 23, Validation Loss: 0.7604
# Epoch 24, Validation Loss: 0.7670
# Epoch 25, Validation Loss: 0.8000
# Epoch 26, Validation Loss: 0.7577
# Epoch 27, Validation Loss: 0.7732
# Epoch 28, Validation Loss: 0.7797
# Epoch 29, Validation Loss: 0.7668
# Epoch 30, Validation Loss: 0.7682
# Early stopping after epoch 30 with validation loss 0.7504
# Test Loss: 0.7273, Test Score: 0.6186 for seed 2 and 25 heads.
# seed 3, with 20 heads
# Epoch 1, Validation Loss: 0.9930
# Epoch 2, Validation Loss: 0.9672
# Epoch 3, Validation Loss: 0.9614
# Epoch 4, Validation Loss: 0.9539
# Epoch 5, Validation Loss: 0.9038
# Epoch 6, Validation Loss: 0.8738
# Epoch 7, Validation Loss: 0.8558
# Epoch 8, Validation Loss: 0.8252
# Epoch 9, Validation Loss: 0.8209
# Epoch 10, Validation Loss: 0.7770
# Epoch 11, Validation Loss: 0.7764
# Epoch 12, Validation Loss: 0.7493
# Epoch 13, Validation Loss: 0.7669
# Epoch 14, Validation Loss: 0.7822
# Epoch 15, Validation Loss: 0.7653
# Epoch 16, Validation Loss: 0.7702
# Epoch 17, Validation Loss: 0.7581
# Epoch 18, Validation Loss: 0.7292
# Epoch 19, Validation Loss: 0.7195
# Epoch 20, Validation Loss: 0.7291
# Epoch 21, Validation Loss: 0.7257
# Epoch 22, Validation Loss: 0.7260
# Epoch 23, Validation Loss: 0.7464
# Epoch 24, Validation Loss: 0.7263
# Epoch 25, Validation Loss: 0.7323
# Epoch 26, Validation Loss: 0.7803
# Epoch 27, Validation Loss: 0.7437
# Epoch 28, Validation Loss: 0.7272
# Epoch 29, Validation Loss: 0.7348
# Early stopping after epoch 29 with validation loss 0.7195
# Test Loss: 0.8080, Test Score: 0.6118 for seed 3 and 20 heads.
# seed 3, with 25 heads
# Epoch 1, Validation Loss: 0.9895
# Epoch 2, Validation Loss: 0.9607
# Epoch 3, Validation Loss: 0.9428
# Epoch 4, Validation Loss: 0.9340
# Epoch 5, Validation Loss: 0.8808
# Epoch 6, Validation Loss: 0.8637
# Epoch 7, Validation Loss: 0.8250
# Epoch 8, Validation Loss: 0.7945
# Epoch 9, Validation Loss: 0.7768
# Epoch 10, Validation Loss: 0.7613
# Epoch 11, Validation Loss: 0.7666
# Epoch 12, Validation Loss: 0.7561
# Epoch 13, Validation Loss: 0.7993
# Epoch 14, Validation Loss: 0.7661
# Epoch 15, Validation Loss: 0.7707
# Epoch 16, Validation Loss: 0.7398
# Epoch 17, Validation Loss: 0.7317
# Epoch 18, Validation Loss: 0.7391
# Epoch 19, Validation Loss: 0.7401
# Epoch 20, Validation Loss: 0.7309
# Epoch 21, Validation Loss: 0.7335
# Epoch 22, Validation Loss: 0.7298
# Epoch 23, Validation Loss: 0.7109
# Epoch 24, Validation Loss: 0.7316
# Epoch 25, Validation Loss: 0.7684
# Epoch 26, Validation Loss: 0.7259
# Epoch 27, Validation Loss: 0.7208
# Epoch 28, Validation Loss: 0.7149
# Epoch 29, Validation Loss: 0.6961
# Epoch 30, Validation Loss: 0.7306
# Epoch 31, Validation Loss: 0.7751
# Epoch 32, Validation Loss: 0.7551
# Epoch 33, Validation Loss: 0.7389
# Epoch 34, Validation Loss: 0.7452
# Epoch 35, Validation Loss: 0.7371
# Epoch 36, Validation Loss: 0.7399
# Epoch 37, Validation Loss: 0.8072
# Epoch 38, Validation Loss: 0.7254
# Epoch 39, Validation Loss: 0.7192
# Early stopping after epoch 39 with validation loss 0.6961
# Test Loss: 0.7866, Test Score: 0.6069 for seed 3 and 25 heads.
# seed 4, with 20 heads
# Epoch 1, Validation Loss: 0.9879
# Epoch 2, Validation Loss: 0.9477
# Epoch 3, Validation Loss: 0.8892
# Epoch 4, Validation Loss: 0.8602
# Epoch 5, Validation Loss: 0.8756
# Epoch 6, Validation Loss: 0.8290
# Epoch 7, Validation Loss: 0.8314
# Epoch 8, Validation Loss: 0.7971
# Epoch 9, Validation Loss: 0.8006
# Epoch 10, Validation Loss: 0.7728
# Epoch 11, Validation Loss: 0.7620
# Epoch 12, Validation Loss: 0.8004
# Epoch 13, Validation Loss: 0.7584
# Epoch 14, Validation Loss: 0.7720
# Epoch 15, Validation Loss: 0.7850
# Epoch 16, Validation Loss: 0.7749
# Epoch 17, Validation Loss: 0.7994
# Epoch 18, Validation Loss: 0.7726
# Epoch 19, Validation Loss: 0.7766
# Epoch 20, Validation Loss: 0.7814
# Epoch 21, Validation Loss: 0.7756
# Epoch 22, Validation Loss: 0.7431
# Epoch 23, Validation Loss: 0.7763
# Epoch 24, Validation Loss: 0.7613
# Epoch 25, Validation Loss: 0.7392
# Epoch 26, Validation Loss: 0.7200
# Epoch 27, Validation Loss: 0.7466
# Epoch 28, Validation Loss: 0.7726
# Epoch 29, Validation Loss: 0.7731
# Epoch 30, Validation Loss: 0.8247
# Epoch 31, Validation Loss: 0.8092
# Epoch 32, Validation Loss: 0.7662
# Epoch 33, Validation Loss: 0.8421
# Epoch 34, Validation Loss: 0.8022
# Epoch 35, Validation Loss: 0.7436
# Epoch 36, Validation Loss: 0.7833
# Early stopping after epoch 36 with validation loss 0.7200
# Test Loss: 0.7987, Test Score: 0.5908 for seed 4 and 20 heads.
# seed 4, with 25 heads
# Epoch 1, Validation Loss: 0.9521
# Epoch 2, Validation Loss: 0.9380
# Epoch 3, Validation Loss: 0.8980
# Epoch 4, Validation Loss: 0.9230
# Epoch 5, Validation Loss: 0.9179
# Epoch 6, Validation Loss: 0.9134
# Epoch 7, Validation Loss: 0.8641
# Epoch 8, Validation Loss: 0.8498
# Epoch 9, Validation Loss: 0.8325
# Epoch 10, Validation Loss: 0.9184
# Epoch 11, Validation Loss: 0.8262
# Epoch 12, Validation Loss: 0.8089
# Epoch 13, Validation Loss: 0.8588
# Epoch 14, Validation Loss: 0.7740
# Epoch 15, Validation Loss: 0.8229
# Epoch 16, Validation Loss: 0.8568
# Epoch 17, Validation Loss: 0.7948
# Epoch 18, Validation Loss: 0.7888
# Epoch 19, Validation Loss: 0.7741
# Epoch 20, Validation Loss: 0.7735
# Epoch 21, Validation Loss: 0.7574
# Epoch 22, Validation Loss: 0.7538
# Epoch 23, Validation Loss: 0.7795
# Epoch 24, Validation Loss: 0.7503
# Epoch 25, Validation Loss: 0.7374
# Epoch 26, Validation Loss: 0.7497
# Epoch 27, Validation Loss: 0.7535
# Epoch 28, Validation Loss: 0.7621
# Epoch 29, Validation Loss: 0.7571
# Epoch 30, Validation Loss: 0.7553
# Epoch 31, Validation Loss: 0.8852
# Epoch 32, Validation Loss: 0.7733
# Epoch 33, Validation Loss: 0.7516
# Epoch 34, Validation Loss: 0.7404
# Epoch 35, Validation Loss: 0.7340
# Epoch 36, Validation Loss: 0.7428
# Epoch 37, Validation Loss: 0.7369
# Epoch 38, Validation Loss: 0.7224
# Epoch 39, Validation Loss: 0.7333
# Epoch 40, Validation Loss: 0.7297
# Epoch 41, Validation Loss: 0.7620
# Epoch 42, Validation Loss: 0.7216
# Epoch 43, Validation Loss: 0.7165
# Epoch 44, Validation Loss: 0.6948
# Epoch 45, Validation Loss: 0.7267
# Epoch 46, Validation Loss: 0.7050
# Epoch 47, Validation Loss: 0.7003
# Epoch 48, Validation Loss: 0.7142
# Epoch 49, Validation Loss: 0.7099
# Epoch 50, Validation Loss: 0.7126
# Epoch 51, Validation Loss: 0.7404
# Epoch 52, Validation Loss: 0.7097
# Epoch 53, Validation Loss: 0.7296
# Epoch 54, Validation Loss: 0.7294
# Early stopping after epoch 54 with validation loss 0.6948
# Test Loss: 0.7416, Test Score: 0.6087 for seed 4 and 25 heads.
# seed 5, with 20 heads
# Epoch 1, Validation Loss: 0.9714
# Epoch 2, Validation Loss: 0.9645
# Epoch 3, Validation Loss: 0.8828
# Epoch 4, Validation Loss: 0.8462
# Epoch 5, Validation Loss: 0.8748
# Epoch 6, Validation Loss: 0.8456
# Epoch 7, Validation Loss: 0.8622
# Epoch 8, Validation Loss: 0.8623
# Epoch 9, Validation Loss: 0.8481
# Epoch 10, Validation Loss: 0.8327
# Epoch 11, Validation Loss: 0.8213
# Epoch 12, Validation Loss: 0.8099
# Epoch 13, Validation Loss: 0.8024
# Epoch 14, Validation Loss: 0.8024
# Epoch 15, Validation Loss: 0.7914
# Epoch 16, Validation Loss: 0.8126
# Epoch 17, Validation Loss: 0.7871
# Epoch 18, Validation Loss: 0.7921
# Epoch 19, Validation Loss: 0.8484
# Epoch 20, Validation Loss: 0.7869
# Epoch 21, Validation Loss: 0.7901
# Epoch 22, Validation Loss: 0.7949
# Epoch 23, Validation Loss: 0.7867
# Epoch 24, Validation Loss: 0.7850
# Epoch 25, Validation Loss: 0.7978
# Epoch 26, Validation Loss: 0.7949
# Epoch 27, Validation Loss: 0.8552
# Epoch 28, Validation Loss: 0.7926
# Epoch 29, Validation Loss: 0.7926
# Epoch 30, Validation Loss: 0.7923
# Epoch 31, Validation Loss: 0.7874
# Epoch 32, Validation Loss: 0.7796
# Epoch 33, Validation Loss: 0.7883
# Epoch 34, Validation Loss: 0.7872
# Epoch 35, Validation Loss: 0.7831
# Epoch 36, Validation Loss: 0.7841
# Epoch 37, Validation Loss: 0.8027
# Epoch 38, Validation Loss: 0.8094
# Epoch 39, Validation Loss: 0.7776
# Epoch 40, Validation Loss: 0.7825
# Epoch 41, Validation Loss: 0.7818
# Epoch 42, Validation Loss: 0.8266
# Epoch 43, Validation Loss: 0.7912
# Epoch 44, Validation Loss: 0.7891
# Epoch 45, Validation Loss: 0.8058
# Epoch 46, Validation Loss: 0.8053
# Epoch 47, Validation Loss: 0.7940
# Epoch 48, Validation Loss: 0.7917
# Epoch 49, Validation Loss: 0.7890
# Early stopping after epoch 49 with validation loss 0.7776
# Test Loss: 0.7295, Test Score: 0.6338 for seed 5 and 20 heads.
# seed 5, with 25 heads
# Epoch 1, Validation Loss: 0.9560
# Epoch 2, Validation Loss: 0.9310
# Epoch 3, Validation Loss: 0.9085
# Epoch 4, Validation Loss: 0.8967
# Epoch 5, Validation Loss: 0.8756
# Epoch 6, Validation Loss: 0.8377
# Epoch 7, Validation Loss: 0.8334
# Epoch 8, Validation Loss: 0.8450
# Epoch 9, Validation Loss: 0.8139
# Epoch 10, Validation Loss: 0.8626
# Epoch 11, Validation Loss: 0.8449
# Epoch 12, Validation Loss: 0.8394
# Epoch 13, Validation Loss: 0.8303
# Epoch 14, Validation Loss: 0.8254
# Epoch 15, Validation Loss: 0.8419
# Epoch 16, Validation Loss: 0.8383
# Epoch 17, Validation Loss: 0.8489
# Epoch 18, Validation Loss: 0.8209
# Epoch 19, Validation Loss: 0.8152
# Early stopping after epoch 19 with validation loss 0.8139
# Test Loss: 0.7918, Test Score: 0.5447 for seed 5 and 25 heads.
# seed 6, with 20 heads
# Epoch 1, Validation Loss: 0.9394
# Epoch 2, Validation Loss: 0.9102
# Epoch 3, Validation Loss: 0.8746
# Epoch 4, Validation Loss: 0.8526
# Epoch 5, Validation Loss: 0.8249
# Epoch 6, Validation Loss: 0.8177
# Epoch 7, Validation Loss: 0.8062
# Epoch 8, Validation Loss: 0.8147
# Epoch 9, Validation Loss: 0.8209
# Epoch 10, Validation Loss: 0.7920
# Epoch 11, Validation Loss: 0.8153
# Epoch 12, Validation Loss: 0.8442
# Epoch 13, Validation Loss: 0.8216
# Epoch 14, Validation Loss: 0.8029
# Epoch 15, Validation Loss: 0.8086
# Epoch 16, Validation Loss: 0.7807
# Epoch 17, Validation Loss: 0.8046
# Epoch 18, Validation Loss: 0.7947
# Epoch 19, Validation Loss: 0.8024
# Epoch 20, Validation Loss: 0.8298
# Epoch 21, Validation Loss: 0.8147
# Epoch 22, Validation Loss: 0.8017
# Epoch 23, Validation Loss: 0.8575
# Epoch 24, Validation Loss: 0.8059
# Epoch 25, Validation Loss: 0.7814
# Epoch 26, Validation Loss: 0.7825
# Early stopping after epoch 26 with validation loss 0.7807
# Test Loss: 0.7770, Test Score: 0.5897 for seed 6 and 20 heads.
# seed 6, with 25 heads
# Epoch 1, Validation Loss: 0.9932
# Epoch 2, Validation Loss: 0.9571
# Epoch 3, Validation Loss: 0.9021
# Epoch 4, Validation Loss: 0.8774
# Epoch 5, Validation Loss: 0.8903
# Epoch 6, Validation Loss: 0.8382
# Epoch 7, Validation Loss: 0.8270
# Epoch 8, Validation Loss: 0.8139
# Epoch 9, Validation Loss: 0.7921
# Epoch 10, Validation Loss: 0.7978
# Epoch 11, Validation Loss: 0.8139
# Epoch 12, Validation Loss: 0.7959
# Epoch 13, Validation Loss: 0.7935
# Epoch 14, Validation Loss: 0.7979
# Epoch 15, Validation Loss: 0.7773
# Epoch 16, Validation Loss: 0.8153
# Epoch 17, Validation Loss: 0.7796
# Epoch 18, Validation Loss: 0.7785
# Epoch 19, Validation Loss: 0.7700
# Epoch 20, Validation Loss: 0.7676
# Epoch 21, Validation Loss: 0.7697
# Epoch 22, Validation Loss: 0.7859
# Epoch 23, Validation Loss: 0.7756
# Epoch 24, Validation Loss: 0.7940
# Epoch 25, Validation Loss: 0.7754
# Epoch 26, Validation Loss: 0.8365
# Epoch 27, Validation Loss: 0.7646
# Epoch 28, Validation Loss: 0.7676
# Epoch 29, Validation Loss: 0.7648
# Epoch 30, Validation Loss: 0.7664
# Epoch 31, Validation Loss: 0.7740
# Epoch 32, Validation Loss: 0.7934
# Epoch 33, Validation Loss: 0.7737
# Epoch 34, Validation Loss: 0.7639
# Epoch 35, Validation Loss: 0.7530
# Epoch 36, Validation Loss: 0.7620
# Epoch 37, Validation Loss: 0.7637
# Epoch 38, Validation Loss: 0.8387
# Epoch 39, Validation Loss: 0.7579
# Epoch 40, Validation Loss: 0.7656
# Epoch 41, Validation Loss: 0.7596
# Epoch 42, Validation Loss: 0.7468
# Epoch 43, Validation Loss: 0.7834
# Epoch 44, Validation Loss: 0.7597
# Epoch 45, Validation Loss: 0.7507
# Epoch 46, Validation Loss: 0.7876
# Epoch 47, Validation Loss: 0.7711
# Epoch 48, Validation Loss: 0.7720
# Epoch 49, Validation Loss: 0.7432
# Epoch 50, Validation Loss: 0.7519
# Epoch 51, Validation Loss: 0.8498
# Epoch 52, Validation Loss: 0.7426
# Epoch 53, Validation Loss: 0.7478
# Epoch 54, Validation Loss: 0.7718
# Epoch 55, Validation Loss: 0.7708
# Epoch 56, Validation Loss: 0.7586
# Epoch 57, Validation Loss: 0.7661
# Epoch 58, Validation Loss: 0.7600
# Epoch 59, Validation Loss: 0.7793
# Epoch 60, Validation Loss: 0.7323
# Epoch 61, Validation Loss: 0.7340
# Epoch 62, Validation Loss: 0.7392
# Epoch 63, Validation Loss: 0.7347
# Epoch 64, Validation Loss: 0.7464
# Epoch 65, Validation Loss: 0.7532
# Epoch 66, Validation Loss: 0.7428
# Epoch 67, Validation Loss: 0.7572
# Epoch 68, Validation Loss: 0.7452
# Epoch 69, Validation Loss: 0.7986
# Epoch 70, Validation Loss: 0.7754
# Early stopping after epoch 70 with validation loss 0.7323
# Test Loss: 0.7916, Test Score: 0.5714 for seed 6 and 25 heads.
# seed 7, with 20 heads
# Epoch 1, Validation Loss: 0.9752
# Epoch 2, Validation Loss: 0.9355
# Epoch 3, Validation Loss: 0.8808
# Epoch 4, Validation Loss: 0.8894
# Epoch 5, Validation Loss: 0.8425
# Epoch 6, Validation Loss: 0.8104
# Epoch 7, Validation Loss: 0.7972
# Epoch 8, Validation Loss: 0.7873
# Epoch 9, Validation Loss: 0.7827
# Epoch 10, Validation Loss: 0.7665
# Epoch 11, Validation Loss: 0.7927
# Epoch 12, Validation Loss: 0.7609
# Epoch 13, Validation Loss: 0.8067
# Epoch 14, Validation Loss: 0.7883
# Epoch 15, Validation Loss: 0.7860
# Epoch 16, Validation Loss: 0.7410
# Epoch 17, Validation Loss: 0.7399
# Epoch 18, Validation Loss: 0.7378
# Epoch 19, Validation Loss: 0.7094
# Epoch 20, Validation Loss: 0.7027
# Epoch 21, Validation Loss: 0.7068
# Epoch 22, Validation Loss: 0.7130
# Epoch 23, Validation Loss: 0.7272
# Epoch 24, Validation Loss: 0.7434
# Epoch 25, Validation Loss: 0.7375
# Epoch 26, Validation Loss: 0.7153
# Epoch 27, Validation Loss: 0.7140
# Epoch 28, Validation Loss: 0.7386
# Epoch 29, Validation Loss: 0.7339
# Epoch 30, Validation Loss: 0.7363
# Early stopping after epoch 30 with validation loss 0.7027
# Test Loss: 0.8193, Test Score: 0.5198 for seed 7 and 20 heads.
# seed 7, with 25 heads
# Epoch 1, Validation Loss: 0.9685
# Epoch 2, Validation Loss: 0.9450
# Epoch 3, Validation Loss: 0.8901
# Epoch 4, Validation Loss: 0.8755
# Epoch 5, Validation Loss: 0.8254
# Epoch 6, Validation Loss: 0.8466
# Epoch 7, Validation Loss: 0.8206
# Epoch 8, Validation Loss: 0.7891
# Epoch 9, Validation Loss: 0.7803
# Epoch 10, Validation Loss: 0.7608
# Epoch 11, Validation Loss: 0.7465
# Epoch 12, Validation Loss: 0.7399
# Epoch 13, Validation Loss: 0.7710
# Epoch 14, Validation Loss: 0.7407
# Epoch 15, Validation Loss: 0.7724
# Epoch 16, Validation Loss: 0.7319
# Epoch 17, Validation Loss: 0.7562
# Epoch 18, Validation Loss: 0.8003
# Epoch 19, Validation Loss: 0.7348
# Epoch 20, Validation Loss: 0.7147
# Epoch 21, Validation Loss: 0.7287
# Epoch 22, Validation Loss: 0.7374
# Epoch 23, Validation Loss: 0.7256
# Epoch 24, Validation Loss: 0.7396
# Epoch 25, Validation Loss: 0.7106
# Epoch 26, Validation Loss: 0.7271
# Epoch 27, Validation Loss: 0.7609
# Epoch 28, Validation Loss: 0.7238
# Epoch 29, Validation Loss: 0.7159
# Epoch 30, Validation Loss: 0.7454
# Epoch 31, Validation Loss: 0.7169
# Epoch 32, Validation Loss: 0.7036
# Epoch 33, Validation Loss: 0.7282
# Epoch 34, Validation Loss: 0.7352
# Epoch 35, Validation Loss: 0.7182
# Epoch 36, Validation Loss: 0.7106
# Epoch 37, Validation Loss: 0.7339
# Epoch 38, Validation Loss: 0.7216
# Epoch 39, Validation Loss: 0.7172
# Epoch 40, Validation Loss: 0.7149
# Epoch 41, Validation Loss: 0.7430
# Epoch 42, Validation Loss: 0.7088
# Early stopping after epoch 42 with validation loss 0.7036
# Test Loss: 0.7731, Test Score: 0.5689 for seed 7 and 25 heads.
# seed 8, with 20 heads
# Epoch 1, Validation Loss: 0.9813
# Epoch 2, Validation Loss: 0.9555
# Epoch 3, Validation Loss: 0.9502
# Epoch 4, Validation Loss: 0.9682
# Epoch 5, Validation Loss: 0.9135
# Epoch 6, Validation Loss: 0.9163
# Epoch 7, Validation Loss: 0.9727
# Epoch 8, Validation Loss: 0.9206
# Epoch 9, Validation Loss: 0.8792
# Epoch 10, Validation Loss: 0.8754
# Epoch 11, Validation Loss: 0.9118
# Epoch 12, Validation Loss: 0.8846
# Epoch 13, Validation Loss: 0.8616
# Epoch 14, Validation Loss: 0.8614
# Epoch 15, Validation Loss: 0.8645
# Epoch 16, Validation Loss: 0.8511
# Epoch 17, Validation Loss: 0.8469
# Epoch 18, Validation Loss: 0.8822
# Epoch 19, Validation Loss: 0.8713
# Epoch 20, Validation Loss: 0.8614
# Epoch 21, Validation Loss: 0.8969
# Epoch 22, Validation Loss: 0.8713
# Epoch 23, Validation Loss: 0.8505
# Epoch 24, Validation Loss: 0.9444
# Epoch 25, Validation Loss: 0.8343
# Epoch 26, Validation Loss: 0.8408
# Epoch 27, Validation Loss: 0.8825
# Epoch 28, Validation Loss: 0.8408
# Epoch 29, Validation Loss: 0.8244
# Epoch 30, Validation Loss: 0.8457
# Epoch 31, Validation Loss: 0.8156
# Epoch 32, Validation Loss: 0.8272
# Epoch 33, Validation Loss: 0.8308
# Epoch 34, Validation Loss: 0.8463
# Epoch 35, Validation Loss: 0.8554
# Epoch 36, Validation Loss: 0.8457
# Epoch 37, Validation Loss: 0.8950
# Epoch 38, Validation Loss: 0.8577
# Epoch 39, Validation Loss: 0.8712
# Epoch 40, Validation Loss: 0.8541
# Epoch 41, Validation Loss: 0.8788
# Early stopping after epoch 41 with validation loss 0.8156
# Test Loss: 0.7662, Test Score: 0.6119 for seed 8 and 20 heads.
# seed 8, with 25 heads
# Epoch 1, Validation Loss: 0.9896
# Epoch 2, Validation Loss: 0.9763
# Epoch 3, Validation Loss: 0.9752
# Epoch 4, Validation Loss: 0.9764
# Epoch 5, Validation Loss: 0.9686
# Epoch 6, Validation Loss: 0.9762
# Epoch 7, Validation Loss: 0.9658
# Epoch 8, Validation Loss: 0.9483
# Epoch 9, Validation Loss: 0.9298
# Epoch 10, Validation Loss: 0.9383
# Epoch 11, Validation Loss: 0.9312
# Epoch 12, Validation Loss: 0.9008
# Epoch 13, Validation Loss: 0.8954
# Epoch 14, Validation Loss: 0.9285
# Epoch 15, Validation Loss: 0.8856
# Epoch 16, Validation Loss: 0.9232
# Epoch 17, Validation Loss: 0.8561
# Epoch 18, Validation Loss: 0.8638
# Epoch 19, Validation Loss: 0.8625
# Epoch 20, Validation Loss: 0.8612
# Epoch 21, Validation Loss: 0.8654
# Epoch 22, Validation Loss: 0.8499
# Epoch 23, Validation Loss: 0.8469
# Epoch 24, Validation Loss: 0.8519
# Epoch 25, Validation Loss: 0.8870
# Epoch 26, Validation Loss: 0.8705
# Epoch 27, Validation Loss: 0.8637
# Epoch 28, Validation Loss: 0.8489
# Epoch 29, Validation Loss: 0.8478
# Epoch 30, Validation Loss: 0.8453
# Epoch 31, Validation Loss: 0.8974
# Epoch 32, Validation Loss: 0.8838
# Epoch 33, Validation Loss: 0.8534
# Epoch 34, Validation Loss: 0.9371
# Epoch 35, Validation Loss: 0.9022
# Epoch 36, Validation Loss: 0.9801
# Epoch 37, Validation Loss: 0.8648
# Epoch 38, Validation Loss: 0.8794
# Epoch 39, Validation Loss: 0.8914
# Epoch 40, Validation Loss: 0.8742
# Early stopping after epoch 40 with validation loss 0.8453
# Test Loss: 0.7755, Test Score: 0.5681 for seed 8 and 25 heads.
# seed 9, with 20 heads
# Epoch 1, Validation Loss: 0.9660
# Epoch 2, Validation Loss: 0.9401
# Epoch 3, Validation Loss: 0.8872
# Epoch 4, Validation Loss: 0.8369
# Epoch 5, Validation Loss: 0.8816
# Epoch 6, Validation Loss: 0.7966
# Epoch 7, Validation Loss: 0.8201
# Epoch 8, Validation Loss: 0.7870
# Epoch 9, Validation Loss: 0.7822
# Epoch 10, Validation Loss: 0.8881
# Epoch 11, Validation Loss: 0.7629
# Epoch 12, Validation Loss: 0.7454
# Epoch 13, Validation Loss: 0.7558
# Epoch 14, Validation Loss: 0.7248
# Epoch 15, Validation Loss: 0.7819
# Epoch 16, Validation Loss: 0.7352
# Epoch 17, Validation Loss: 0.7195
# Epoch 18, Validation Loss: 0.7241
# Epoch 19, Validation Loss: 0.7505
# Epoch 20, Validation Loss: 0.7440
# Epoch 21, Validation Loss: 0.7747
# Epoch 22, Validation Loss: 0.7534
# Epoch 23, Validation Loss: 0.7596
# Epoch 24, Validation Loss: 0.7564
# Epoch 25, Validation Loss: 0.7614
# Epoch 26, Validation Loss: 0.7705
# Epoch 27, Validation Loss: 0.7715
# Early stopping after epoch 27 with validation loss 0.7195
# Test Loss: 0.7836, Test Score: 0.5512 for seed 9 and 20 heads.
# seed 9, with 25 heads
# Epoch 1, Validation Loss: 1.0021
# Epoch 2, Validation Loss: 0.9492
# Epoch 3, Validation Loss: 0.8876
# Epoch 4, Validation Loss: 0.8343
# Epoch 5, Validation Loss: 0.8526
# Epoch 6, Validation Loss: 0.8243
# Epoch 7, Validation Loss: 0.7915
# Epoch 8, Validation Loss: 0.8285
# Epoch 9, Validation Loss: 0.7974
# Epoch 10, Validation Loss: 0.7656
# Epoch 11, Validation Loss: 0.7842
# Epoch 12, Validation Loss: 0.7595
# Epoch 13, Validation Loss: 0.7441
# Epoch 14, Validation Loss: 0.7558
# Epoch 15, Validation Loss: 0.7473
# Epoch 16, Validation Loss: 0.7496
# Epoch 17, Validation Loss: 0.7164
# Epoch 18, Validation Loss: 0.7336
# Epoch 19, Validation Loss: 0.7140
# Epoch 20, Validation Loss: 0.7390
# Epoch 21, Validation Loss: 0.7221
# Epoch 22, Validation Loss: 0.7694
# Epoch 23, Validation Loss: 0.7208
# Epoch 24, Validation Loss: 0.7815
# Epoch 25, Validation Loss: 0.7514
# Epoch 26, Validation Loss: 0.7318
# Epoch 27, Validation Loss: 0.7012
# Epoch 28, Validation Loss: 0.7144
# Epoch 29, Validation Loss: 0.7060
# Epoch 30, Validation Loss: 0.7527
# Epoch 31, Validation Loss: 0.7235
# Epoch 32, Validation Loss: 0.7173
# Epoch 33, Validation Loss: 0.7223
# Epoch 34, Validation Loss: 0.7188
# Epoch 35, Validation Loss: 0.7363
# Epoch 36, Validation Loss: 0.7226
# Epoch 37, Validation Loss: 0.7167
# Early stopping after epoch 37 with validation loss 0.7012
# Test Loss: 0.7670, Test Score: 0.6166 for seed 9 and 25 heads.
# seed 10, with 20 heads
# Epoch 1, Validation Loss: 0.9471
# Epoch 2, Validation Loss: 0.9100
# Epoch 3, Validation Loss: 0.8657
# Epoch 4, Validation Loss: 0.8809
# Epoch 5, Validation Loss: 0.8385
# Epoch 6, Validation Loss: 0.8141
# Epoch 7, Validation Loss: 0.7651
# Epoch 8, Validation Loss: 0.7962
# Epoch 9, Validation Loss: 0.7865
# Epoch 10, Validation Loss: 0.7597
# Epoch 11, Validation Loss: 0.7804
# Epoch 12, Validation Loss: 0.7662
# Epoch 13, Validation Loss: 0.7433
# Epoch 14, Validation Loss: 0.7522
# Epoch 15, Validation Loss: 0.7580
# Epoch 16, Validation Loss: 0.7557
# Epoch 17, Validation Loss: 0.7033
# Epoch 18, Validation Loss: 0.7008
# Epoch 19, Validation Loss: 0.7844
# Epoch 20, Validation Loss: 0.6913
# Epoch 21, Validation Loss: 0.7055
# Epoch 22, Validation Loss: 0.7003
# Epoch 23, Validation Loss: 0.6840
# Epoch 24, Validation Loss: 0.6828
# Epoch 25, Validation Loss: 0.6894
# Epoch 26, Validation Loss: 0.7636
# Epoch 27, Validation Loss: 0.6884
# Epoch 28, Validation Loss: 0.6840
# Epoch 29, Validation Loss: 0.6900
# Epoch 30, Validation Loss: 0.7082
# Epoch 31, Validation Loss: 0.7106
# Epoch 32, Validation Loss: 0.6867
# Epoch 33, Validation Loss: 0.6873
# Epoch 34, Validation Loss: 0.6925
# Early stopping after epoch 34 with validation loss 0.6828
# Test Loss: 0.7365, Test Score: 0.6230 for seed 10 and 20 heads.
# seed 10, with 25 heads
# Epoch 1, Validation Loss: 0.9548
# Epoch 2, Validation Loss: 0.8450
# Epoch 3, Validation Loss: 0.8102
# Epoch 4, Validation Loss: 0.8215
# Epoch 5, Validation Loss: 0.8098
# Epoch 6, Validation Loss: 0.7683
# Epoch 7, Validation Loss: 0.7891
# Epoch 8, Validation Loss: 0.7662
# Epoch 9, Validation Loss: 0.7522
# Epoch 10, Validation Loss: 0.7466
# Epoch 11, Validation Loss: 0.7434
# Epoch 12, Validation Loss: 0.7320
# Epoch 13, Validation Loss: 0.7269
# Epoch 14, Validation Loss: 0.7281
# Epoch 15, Validation Loss: 0.7169
# Epoch 16, Validation Loss: 0.7109
# Epoch 17, Validation Loss: 0.7437
# Epoch 18, Validation Loss: 0.7300
# Epoch 19, Validation Loss: 0.7427
# Epoch 20, Validation Loss: 0.7160
# Epoch 21, Validation Loss: 0.7035
# Epoch 22, Validation Loss: 0.7135
# Epoch 23, Validation Loss: 0.7640
# Epoch 24, Validation Loss: 0.7095
# Epoch 25, Validation Loss: 0.7074
# Epoch 26, Validation Loss: 0.6999
# Epoch 27, Validation Loss: 0.7427
# Epoch 28, Validation Loss: 0.6999
# Epoch 29, Validation Loss: 0.6963
# Epoch 30, Validation Loss: 0.7023
# Epoch 31, Validation Loss: 0.7259
# Epoch 32, Validation Loss: 0.6915
# Epoch 33, Validation Loss: 0.7302
# Epoch 34, Validation Loss: 0.7111
# Epoch 35, Validation Loss: 0.6798
# Epoch 36, Validation Loss: 0.6884
# Epoch 37, Validation Loss: 0.6966
# Epoch 38, Validation Loss: 0.6999
# Epoch 39, Validation Loss: 0.6878
# Epoch 40, Validation Loss: 0.6859
# Epoch 41, Validation Loss: 0.6972
# Epoch 42, Validation Loss: 0.6851
# Epoch 43, Validation Loss: 0.6928
# Epoch 44, Validation Loss: 0.6907
# Epoch 45, Validation Loss: 0.6848
# Early stopping after epoch 45 with validation loss 0.6798
# Test Loss: 0.7402, Test Score: 0.5910 for seed 10 and 25 heads.
