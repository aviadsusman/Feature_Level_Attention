# %%
import utils as u
from importlib import reload
from sklearn.model_selection import train_test_split
import fla_parallelized as a
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import time
import numpy as np
from sklearn.metrics import f1_score
import pickle as pkl

# %%
X, y, weight = u.diabetes_data()

# %%
reload(a)
head_counts = [3]#,2,3,4,5,6,7,8,9,10,15,20]
test_prediction_dict = {h: [] for h in head_counts}
test_label_list = []
losses = {h: [] for h in head_counts}

forward_times = []
loss_times = []
backwards_times = []
optimizer_times = []

for seed in range(10):
    for i, head in enumerate(head_counts):
        print(f'seed {seed+1}, with {head} heads')
        #split data
        X_train, X_test, y_train, y_test = train_test_split(X,y, stratify=y, test_size=0.2, random_state=seed)
        X_train, X_val, y_train, y_val = train_test_split(X_train,y_train, stratify=y_train, test_size=0.1, random_state=seed)
        train_dataset = a.npDataset(X_train,y_train)
        test_dataset = a.npDataset(X_test,y_test)
        val_dataset = a.npDataset(X_val,y_val)
        batch_size = 64
        train_loader = DataLoader(train_dataset, batch_size, shuffle=True)
        test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
        val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

        #make model
        hidden_dims = [50,25,10]
        attn_heads = head
        model = a.UFLANN(input_dim=108, hidden_dims=hidden_dims, output_dim=1, 
                                          attn_heads=attn_heads, agg='sum', activation=nn.ReLU)
        criterion = nn.BCEWithLogitsLoss(pos_weight=weight)
        optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

        #train
        num_epochs = 500
        best_val_loss = float('inf')
        best_model = None
        patience = 10
        early_stop_counter = 0
        for epoch in range(num_epochs):
            model.train()
            for inputs, labels in train_loader:
                optimizer.zero_grad()
                start_f = time.time()
                outputs = model(inputs)
                end_f = time.time()
                # print(f'forwards: {end_f-start_f:.4f}')
                forward_times.append(end_f-start_f)
                labels = labels.unsqueeze(1)
                start_l = time.time()
                loss = criterion(outputs, labels)
                end_l = time.time()
                loss_times.append(end_l-start_l)
                start_b = time.time()
                loss.backward()
                end_b = time.time()
                # print(f'back: {end_b-start_b:.4f}')
                backwards_times.append(end_b-start_b)
                start_o = time.time()
                optimizer.step()
                end_o = time.time()
                optimizer_times.append(end_o-start_o)

            model.eval()
            val_losses = []
            for inputs, labels in val_loader:
                with torch.no_grad():
                    outputs = model(inputs)
                    labels = labels.unsqueeze(1)
                    val_loss = criterion(outputs, labels)
                    val_losses.append(val_loss.item())
            
            avg_val_loss = np.mean(val_losses)
            print(f'Epoch {epoch+1}, Validation Loss: {avg_val_loss:.4f}')
            if avg_val_loss < best_val_loss:
                best_val_loss = avg_val_loss
                best_model = model.state_dict()
                early_stop_counter = 0
            else:
                early_stop_counter += 1
            
            if early_stop_counter >= patience:
                print(f'Early stopping after epoch {epoch+1} with validation loss {best_val_loss:.4f}')
                break
            
        model.load_state_dict(best_model)

        #eval
        test_losses = []
        test_predictions = []
        test_true_labels = []

        for inputs, labels in test_loader:
            with torch.no_grad():
                outputs = model(inputs)
                labels = labels.unsqueeze(1)
                test_loss = criterion(outputs, labels)
                test_losses.append(test_loss.item())
                test_predictions.extend(outputs.cpu().numpy())
                test_true_labels.extend(labels.cpu().numpy())
        avg_test_loss = np.mean(test_losses)
        test_predictions_f1 = [torch.sigmoid(y)>0.5 for y in test_predictions]
        test_score = f1_score(test_true_labels, test_predictions_f1)
        print(f'Test Loss: {avg_test_loss:.4f}, Test Score: {test_score:.4f} for seed {seed+1} and {head} heads.')
        if i == 0:
            test_label_list.append(test_true_labels)
        test_prediction_dict[head].append(test_predictions)
        losses[head].append(avg_test_loss)
# with open ("/Users/aviadsusman/Documents/Python_Projects/FeatureLevelAttention/FLA/results/diabetes/film/test_pred_dict_1_to_4.pkl", "wb") as file:
#     pkl.dump(test_prediction_dict, file=file)
# with open ("/Users/aviadsusman/Documents/Python_Projects/FeatureLevelAttention/FLA/results/diabetes/film/test_losses_dict_1_to_4.pkl", "wb") as file:
#     pkl.dump(losses, file=file)
# with open ("/Users/aviadsusman/Documents/Python_Projects/FeatureLevelAttention/FLA/results/diabetes/film/test_labels.pkl", "wb") as file:
#     pkl.dump(test_label_list, file=file)
# Out:
# seed 1, with 3 heads
# Epoch 1, Validation Loss: 1.1405
# Epoch 2, Validation Loss: 1.1446
# Epoch 3, Validation Loss: 1.1380
# Epoch 4, Validation Loss: 1.1129
# Epoch 5, Validation Loss: 1.1283
# Epoch 6, Validation Loss: 1.1447
# Epoch 7, Validation Loss: 1.1428
# Epoch 8, Validation Loss: 1.1660
# Epoch 9, Validation Loss: 1.2169
# Epoch 10, Validation Loss: 1.2022
# Epoch 11, Validation Loss: 1.1746
# Epoch 12, Validation Loss: 1.2019
# Epoch 13, Validation Loss: 1.2016
# Epoch 14, Validation Loss: 1.2649
# Early stopping after epoch 14 with validation loss 1.1129
# Test Loss: 1.3180, Test Score: 0.2616 for seed 1 and 3 heads.
# seed 2, with 3 heads
# Epoch 1, Validation Loss: 1.1711
# Epoch 2, Validation Loss: 1.1319
# Epoch 3, Validation Loss: 1.1246
# Epoch 4, Validation Loss: 1.1225
# Epoch 5, Validation Loss: 1.1361
# Epoch 6, Validation Loss: 1.1292
# Epoch 7, Validation Loss: 1.1103
# Epoch 8, Validation Loss: 1.1576
# Epoch 9, Validation Loss: 1.1363
# Epoch 10, Validation Loss: 1.1762
# Epoch 11, Validation Loss: 1.1664
# Epoch 12, Validation Loss: 1.1745
# Epoch 13, Validation Loss: 1.2003
# Epoch 14, Validation Loss: 1.2029
# Epoch 15, Validation Loss: 1.2451
# Epoch 16, Validation Loss: 1.2527
# Epoch 17, Validation Loss: 1.3053
# Early stopping after epoch 17 with validation loss 1.1103
# Test Loss: 1.3981, Test Score: 0.2857 for seed 2 and 3 heads.
# seed 3, with 3 heads
# Epoch 1, Validation Loss: 1.1331
# Epoch 2, Validation Loss: 1.1214
# Epoch 3, Validation Loss: 1.1192
# Epoch 4, Validation Loss: 1.1048
# Epoch 5, Validation Loss: 1.1233
# Epoch 6, Validation Loss: 1.1253
# Epoch 7, Validation Loss: 1.1303
# Epoch 8, Validation Loss: 1.1282
# Epoch 9, Validation Loss: 1.1343
# Epoch 10, Validation Loss: 1.1525
# Epoch 11, Validation Loss: 1.1897
# Epoch 12, Validation Loss: 1.1712
# Epoch 13, Validation Loss: 1.2007
# Epoch 14, Validation Loss: 1.2278
# Early stopping after epoch 14 with validation loss 1.1048
# Test Loss: 1.3574, Test Score: 0.2696 for seed 3 and 3 heads.
# seed 4, with 3 heads
# Epoch 1, Validation Loss: 1.1848
# Epoch 2, Validation Loss: 1.1517
# Epoch 3, Validation Loss: 1.1466
# Epoch 4, Validation Loss: 1.1303
# Epoch 5, Validation Loss: 1.1374
# Epoch 6, Validation Loss: 1.1615
# Epoch 7, Validation Loss: 1.1531
# Epoch 8, Validation Loss: 1.2180
# Epoch 9, Validation Loss: 1.1587
# Epoch 10, Validation Loss: 1.1740
# Epoch 11, Validation Loss: 1.2498
# Epoch 12, Validation Loss: 1.2469
# Epoch 13, Validation Loss: 1.2907
# Epoch 14, Validation Loss: 1.3619
# Early stopping after epoch 14 with validation loss 1.1303
# Test Loss: 1.3433, Test Score: 0.2665 for seed 4 and 3 heads.
# seed 5, with 3 heads
# Epoch 1, Validation Loss: 1.1477
# Epoch 2, Validation Loss: 1.1315
# Epoch 3, Validation Loss: 1.1217
# Epoch 4, Validation Loss: 1.1256
# Epoch 5, Validation Loss: 1.1420
# Epoch 6, Validation Loss: 1.1292
# Epoch 7, Validation Loss: 1.1480
# Epoch 8, Validation Loss: 1.1788
# Epoch 9, Validation Loss: 1.1474
# Epoch 10, Validation Loss: 1.1817
# Epoch 11, Validation Loss: 1.1886
# Epoch 12, Validation Loss: 1.2255
# Epoch 13, Validation Loss: 1.2858
# Early stopping after epoch 13 with validation loss 1.1217
# Test Loss: 1.4105, Test Score: 0.2527 for seed 5 and 3 heads.
# seed 6, with 3 heads
# Epoch 1, Validation Loss: 1.1690
# Epoch 2, Validation Loss: 1.1249
# Epoch 3, Validation Loss: 1.1199
# Epoch 4, Validation Loss: 1.1130
# Epoch 5, Validation Loss: 1.1041
# Epoch 6, Validation Loss: 1.1295
# Epoch 7, Validation Loss: 1.1049
# Epoch 8, Validation Loss: 1.1357
# Epoch 9, Validation Loss: 1.1224
# Epoch 10, Validation Loss: 1.1673
# Epoch 11, Validation Loss: 1.1779
# Epoch 12, Validation Loss: 1.2017
# Epoch 13, Validation Loss: 1.2103
# Epoch 14, Validation Loss: 1.3052
# Epoch 15, Validation Loss: 1.2637
# Early stopping after epoch 15 with validation loss 1.1041
# Test Loss: 1.2949, Test Score: 0.2673 for seed 6 and 3 heads.
# seed 7, with 3 heads
# Epoch 1, Validation Loss: 1.1786
# Epoch 2, Validation Loss: 1.1330
# Epoch 3, Validation Loss: 1.1141
# Epoch 4, Validation Loss: 1.1130
# Epoch 5, Validation Loss: 1.1089
# Epoch 6, Validation Loss: 1.1110
# Epoch 7, Validation Loss: 1.1087
# Epoch 8, Validation Loss: 1.1548
# Epoch 9, Validation Loss: 1.1605
# Epoch 10, Validation Loss: 1.1903
# Epoch 11, Validation Loss: 1.2229
# Epoch 12, Validation Loss: 1.2858
# Epoch 13, Validation Loss: 1.2427
# Epoch 14, Validation Loss: 1.3185
# Epoch 15, Validation Loss: 1.3601
# Epoch 16, Validation Loss: 1.2991
# Epoch 17, Validation Loss: 1.4706
# Early stopping after epoch 17 with validation loss 1.1087
# Test Loss: 1.4795, Test Score: 0.2738 for seed 7 and 3 heads.
# seed 8, with 3 heads
# Epoch 1, Validation Loss: 1.1447
# Epoch 2, Validation Loss: 1.1330
# Epoch 3, Validation Loss: 1.1415
# Epoch 4, Validation Loss: 1.1515
# Epoch 5, Validation Loss: 1.1586
# Epoch 6, Validation Loss: 1.1618
# Epoch 7, Validation Loss: 1.1686
# Epoch 8, Validation Loss: 1.2010
# Epoch 9, Validation Loss: 1.2434
# Epoch 10, Validation Loss: 1.2150
# Epoch 11, Validation Loss: 1.2438
# Epoch 12, Validation Loss: 1.2728
# Early stopping after epoch 12 with validation loss 1.1330
# Test Loss: 1.2879, Test Score: 0.2677 for seed 8 and 3 heads.
# seed 9, with 3 heads
# Epoch 1, Validation Loss: 1.1459
# Epoch 2, Validation Loss: 1.1633
# Epoch 3, Validation Loss: 1.1480
# Epoch 4, Validation Loss: 1.1506
# Epoch 5, Validation Loss: 1.1328
# Epoch 6, Validation Loss: 1.1339
# Epoch 7, Validation Loss: 1.1585
# Epoch 8, Validation Loss: 1.1671
# Epoch 9, Validation Loss: 1.1791
# Epoch 10, Validation Loss: 1.1696
# Epoch 11, Validation Loss: 1.2129
# Epoch 12, Validation Loss: 1.2091
# Epoch 13, Validation Loss: 1.2086
# Epoch 14, Validation Loss: 1.2904
# Epoch 15, Validation Loss: 1.3246
# Early stopping after epoch 15 with validation loss 1.1328
# Test Loss: 1.3199, Test Score: 0.2687 for seed 9 and 3 heads.
# seed 10, with 3 heads
# Epoch 1, Validation Loss: 1.1636
# Epoch 2, Validation Loss: 1.1643
# Epoch 3, Validation Loss: 1.1338
# Epoch 4, Validation Loss: 1.1257
# Epoch 5, Validation Loss: 1.1557
# Epoch 6, Validation Loss: 1.1421
# Epoch 7, Validation Loss: 1.1370
# Epoch 8, Validation Loss: 1.1399
# Epoch 9, Validation Loss: 1.1415
# Epoch 10, Validation Loss: 1.2160
# Epoch 11, Validation Loss: 1.1408
# Epoch 12, Validation Loss: 1.2423
# Epoch 13, Validation Loss: 1.2168
# Epoch 14, Validation Loss: 1.3661
# Early stopping after epoch 14 with validation loss 1.1257
# Test Loss: 1.3913, Test Score: 0.2345 for seed 10 and 3 heads.

# %%
for k,v in losses.items():
    print(k, np.median(v))
# Out:
# 3 1.3503891726334891

# %%
fmaxes = {}
for k,v in test_prediction_dict.items():
    fmaxes[k] = []
    for i in range(10):
        activated_preds = [u.sig(x) for x in v[i]]
        fmaxes[k].append(u.fmax_score(test_label_list[i], activated_preds)[0])
    print(k, np.median(fmaxes[k]))
# Out:
# 3 0.28841569652024035

# %%
import pandas as pd
import matplotlib.pyplot as plt
fmaxes_df = pd.DataFrame(fmaxes)
fmaxes_df.plot.box()
plt.show()

# %%
import pickle as pkl
with open ("/Users/aviadsusman/Documents/Python_Projects/FeatureLevelAttention/FLA/results/film/sum/diabetes/test_pred_dict.pkl", "wb") as file:
    pkl.dump(test_prediction_dict, file=file)
with open ("/Users/aviadsusman/Documents/Python_Projects/FeatureLevelAttention/FLA/results/film/sum/diabetes/test_losses_dict.pkl", "wb") as file:
    pkl.dump(losses, file=file)
with open ("/Users/aviadsusman/Documents/Python_Projects/FeatureLevelAttention/FLA/results/film/sum/diabetes/test_labels.pkl", "wb") as file:
    pkl.dump(test_label_list, file=file)
